# %% [markdown]
# # 1. Samsung

# %%
import glob
import pandas as pd
from datetime import datetime
import os
from dateutil import parser
import numpy as np
import matplotlib.pyplot as plt

# %%
def excel_to_dataframe(excel_path):
    df1 = pd.read_excel(excel_path, sheet_name = 'Monthly', usecols = 'A', names=['device'],header=None)
    df1['support_type'] = 'Monthly'
    df1['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')

    df2 = pd.read_excel(excel_path, sheet_name = 'Quarterly', usecols = 'A', names=['device'],header=None)
    df2['support_type'] = 'Quarterly'
    df2['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')

    try:
        df3 = pd.read_excel(excel_path, sheet_name = 'Other', usecols = 'A', names=['device'],header=None)
        df3['support_type'] = 'Biannually'
        df3['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')
    except ValueError:
        try: 
            df3 = pd.read_excel(excel_path, sheet_name = 'Biannual', usecols = 'A', names=['device'],header=None)
            df3['support_type'] = 'Biannually'
            df3['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')
        except ValueError:
            df3 = pd.DataFrame([])
        
    try:
        df4 = pd.read_excel(excel_path, sheet_name = 'Wearable', usecols = 'A', names=['device'],header=None)
        df4['support_type'] = 'Wearable'
        df4['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')
    except ValueError:
        df4 = pd.DataFrame([])

    df = pd.concat([df1,df2,df3,df4])
    return df


def get_support_timeline(device,dataset):

    df = dataset
    
    #print('Getting support timeline for {}!'.format(device))
    
    df_device = df[df.device == device].sort_values(by='date')
    
    try:
        monthly_start = df_device[df_device.support_type == 'Monthly'].iloc[0]['date']
        monthly_end = df_device[df_device.support_type == 'Monthly'].iloc[-1]['date']
    except IndexError:
        monthly_start = None
        monthly_end = None
        
    try: 
        quarterly_start = df_device[df_device.support_type == 'Quarterly'].iloc[0]['date']
        quarterly_end = df_device[df_device.support_type == 'Quarterly'].iloc[-1]['date']
    except IndexError:
        quarterly_start = None
        quarterly_end = None
        
    try:
        biannually_start = df_device[df_device.support_type == 'Biannually'].iloc[0]['date']
        biannually_end = df_device[df_device.support_type == 'Biannually'].iloc[-1]['date']
    except IndexError:
        biannually_start = None
        biannually_end = None
    
    try:
        wearable_start = df_device[df_device.support_type == 'Wearable'].iloc[0]['date']
        wearable_end = df_device[df_device.support_type == 'Wearable'].iloc[-1]['date']
    except IndexError:
        wearable_start = None
        wearable_end = None
    result = [monthly_start,monthly_end,quarterly_start,quarterly_end,biannually_start,biannually_end,wearable_start,wearable_end]
    
    return result

# %%
dir_path = '../Data/Samsung/samsung-support-lists/'

print('Getting lists from {}'.format(dir_path))

excel_files = glob.glob(dir_path + '*.xlsx')
df_final = pd.DataFrame([])
for file in excel_files[:]:
    df_new = excel_to_dataframe(file)
    df_final = pd.concat([df_final,df_new],ignore_index=True)

df_final.to_csv('../Data/Samsung/support_lists.csv',index=False)

print('Converting excel files to DataFrame is done!')

df_timelines = pd.DataFrame()
for device in df_final['device'].unique():
    
    support_timeline = get_support_timeline(device,df_final)
    
    df_new = pd.DataFrame({"device": device, 
                           "monthly_start": support_timeline[0],
                           "monthly_end": support_timeline[1],
                           "quarterly_start": support_timeline[2],
                           "quarterly_end": support_timeline[3],
                           "biannually_start": support_timeline[4],
                           "biannually_end": support_timeline[5],
                           "wearable_start": support_timeline[6],
                           "wearable_end": support_timeline[7]},
                          index=[0])
 
    
    df_timelines = pd.concat([df_timelines,df_new],ignore_index=True)

df_timelines.to_csv('../Data/Samsung/timelines_samsung_devices_v1.csv',index=False)

df_timelines.head()
# Out:
# Getting lists from ../Data/Samsung/samsung-support-lists/
# Converting excel files to DataFrame is done!
#               device        monthly_start          monthly_end  \
# 0        Galaxy Fold  2019-10-08 22:18:41  2022-11-04 17:25:38
# 1     Galaxy Fold 5G  2020-12-10 23:59:35  2022-11-04 17:25:38
# 2     Galaxy Z Fold2  2020-09-14 17:19:27  2023-04-04 00:30:35
# 3  Galaxy Z Fold2 5G  2020-09-14 17:19:27  2023-04-04 00:30:35
# 4      Galaxy Z Flip  2020-03-03 11:31:08  2023-04-04 00:30:35
#
#        quarterly_start        quarterly_end biannually_start biannually_end  \
# 0  2022-11-08 08:46:24  2023-04-04 00:30:35              NaT            NaT
# 1  2022-11-08 08:46:24  2023-04-04 00:30:35              NaT            NaT
# 2                 None                 None              NaT            NaT
# 3                 None                 None              NaT            NaT
# 4                 None                 None              NaT            NaT
#
#   wearable_start wearable_end
# 0            NaT          NaT
# 1            NaT          NaT
# 2            NaT          NaT
# 3            NaT          NaT
# 4            NaT          NaT

# %%
print('First snapshot: {}'.format(df_final['date'].min()))
print('Last snapshot: {}'.format(df_final['date'].max()))
print('All snapshots: {}'.format(len(df_final['date'].unique())))
print('Last snapshot: {}'.format(df_final['date'].max()))
print('Avg snapshot: {}'.format((df_final['date'].max()-df_final['date'].min()).days/len(df_final['date'].unique())))
print('Unique Devices: {}'.format(len(df_timelines.index)))
# Out:
# First snapshot: 2017-10-03 06:11:44
# Last snapshot: 2023-04-04 00:30:35
# All snapshots: 507
# Last snapshot: 2023-04-04 00:30:35
# Avg snapshot: 3.9605522682445757
# Unique Devices: 258

# %%
len(df_final['device'].unique())
# Out:
# 258

# %%
df = pd.read_csv('../Data/Samsung/timelines_samsung_devices_v1.csv')

date_first_list = '2017-10-03 06:11:44' # remove the first because maybe the device was already receving before
date_last_list = '2023-04-04 00:30:35' # remove the last because maybe the device will continue to receive 
date_nat = pd.Timestamp('NaT').to_pydatetime()

for column in df.columns:
    df.at[(df[column] == date_first_list) | (df[column] == date_last_list), column] = date_nat
    
df.to_csv('../Data/Samsung/timelines_samsung_devices_v2.csv',index=False)

df.head()
# Out:
#               device        monthly_start          monthly_end  \
# 0        Galaxy Fold  2019-10-08 22:18:41  2022-11-04 17:25:38
# 1     Galaxy Fold 5G  2020-12-10 23:59:35  2022-11-04 17:25:38
# 2     Galaxy Z Fold2  2020-09-14 17:19:27                  NaT
# 3  Galaxy Z Fold2 5G  2020-09-14 17:19:27                  NaT
# 4      Galaxy Z Flip  2020-03-03 11:31:08                  NaT
#
#        quarterly_start quarterly_end biannually_start biannually_end  \
# 0  2022-11-08 08:46:24           NaT              NaN            NaN
# 1  2022-11-08 08:46:24           NaT              NaN            NaN
# 2                  NaN           NaN              NaN            NaN
# 3                  NaN           NaN              NaN            NaN
# 4                  NaN           NaN              NaN            NaN
#
#   wearable_start wearable_end
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN

# %%
df_timelines = pd.read_csv('../Data/Samsung/timelines_samsung_devices_v2.csv')
    
df_timelines[['monthly_start','monthly_end','quarterly_start','quarterly_end','biannually_start','biannually_end']] = df_timelines[['monthly_start','monthly_end','quarterly_start','quarterly_end','biannually_start','biannually_end']].apply(pd.to_datetime)
df_timelines['monthly_duration'] = df_timelines['monthly_end']-df_timelines['monthly_start']
df_timelines['quarterly_duration'] = df_timelines['quarterly_end']-df_timelines['quarterly_start']
df_timelines['biannually_duration'] = df_timelines['biannually_end']-df_timelines['biannually_start']

df_timelines.to_csv('../Data/Samsung/timelines_samsung_devices_v3.csv',index=False)

cond1 = ~(df_timelines['monthly_duration'].dt.days==0) #filter out if only one time appeared in the list
cond2 = ~df_timelines['monthly_duration'].isnull() #filter out as no monthly duration can be calculated

df_timelines_monthly = df_timelines[cond1&cond2].reset_index(drop=True)

cond3 = ~(df_timelines['quarterly_duration'].dt.days==0) #filter out if only one time appeared in the list
cond4 = ~df_timelines['quarterly_duration'].isnull() #filter out as no monthly duration can be calculated

df_timelines_quarterly = df_timelines[cond3&cond4].reset_index(drop=True)


cond5 = ~(df_timelines['biannually_duration'].dt.days==0) #filter out if only one time appeared in the list
cond6 = ~df_timelines['biannually_duration'].isnull() #filter out as no monthly duration can be calculated

df_timelines_biannual = df_timelines[cond5&cond6].reset_index(drop=True)


print("Avg monthly support duration: {}".format(df_timelines_monthly['monthly_duration'].mean(skipna=True)))
print('Monthly completed periods for: {} devices'.format(len(df_timelines_monthly['device'].unique())))

print("Avg quarterly support duration: {}".format(df_timelines_quarterly['quarterly_duration'].mean(skipna=True)))
print('Quarterly completed periods for: {} devices'.format(len(df_timelines_quarterly['device'].unique())))

print("Avg binannually support duration: {}".format(df_timelines_biannual['biannually_duration'].mean(skipna=True)))
print('Biannually completed periods for: {} devices'.format(len(df_timelines_biannual['device'].unique())))
# Out:
# Avg monthly support duration: 1044 days 03:57:27.250000
# Monthly completed periods for: 20 devices
# Avg quarterly support duration: 573 days 07:37:50.900000008
# Quarterly completed periods for: 110 devices
# Avg binannually support duration: 580 days 05:38:34.420000
# Biannually completed periods for: 50 devices

# %%
df_timelines_tablets = df_timelines[df_timelines['device'].str.contains('Tab')]

df_timelines_tablets
# Out:
#                              device monthly_start monthly_end  \
# 87            Galaxy Tab A 8 (2019)           NaT         NaT
# 88          Galaxy Tab A 8.4 (2020)           NaT         NaT
# 89                    Galaxy Tab A7           NaT         NaT
# 90               Galaxy Tab A7 Lite           NaT         NaT
# 91               Galaxy Tab Active2           NaT         NaT
# 92            Galaxy Tab Active Pro           NaT         NaT
# 93               Galaxy Tab Active3           NaT         NaT
# 94                    Galaxy Tab S6           NaT         NaT
# 95                 Galaxy Tab S6 5G           NaT         NaT
# 96               Galaxy Tab S6 Lite           NaT         NaT
# 97                    Galaxy Tab S7           NaT         NaT
# 98                   Galaxy Tab S7+           NaT         NaT
# 99                 Galaxy Tab S7 FE           NaT         NaT
# 139             Galaxy Tab A (2017)           NaT         NaT
# 140        Galaxy Tab A 10.5 (2018)           NaT         NaT
# 141                   Galaxy Tab S4           NaT         NaT
# 142          Galaxy Tab E 8 Refresh           NaT         NaT
# 143        Galaxy Tab A 10.1 (2019)           NaT         NaT
# 144         Galaxy Tab A with S pen           NaT         NaT
# 145                  Galaxy Tab S5e           NaT         NaT
# 153      Galaxy Tab A 8 Plus (2019)           NaT         NaT
# 161        Galaxy Tab A 10.1 (2016)           NaT         NaT
# 162                   Galaxy Tab S3           NaT         NaT
# 168         Galaxy Tab S2 L Refresh           NaT         NaT
# 169         Galaxy Tab S2 S Refresh           NaT         NaT
# 181  Galaxy Tab A with S pen (2019)           NaT         NaT
# 198                   Galaxy Tab A8           NaT         NaT
# 199                   Galaxy Tab S8           NaT         NaT
# 200                  Galaxy Tab S8+           NaT         NaT
# 201             Galaxy Tab S8 Ultra           NaT         NaT
# 215          Galaxy Tab Active4 Pro           NaT         NaT
# 234               Galaxy Tab S3 9.7           NaT         NaT
# 235              Galaxy Tab S4 10.5           NaT         NaT
# 236      Galaxy Tab E (8.0) Refresh           NaT         NaT
# 237               Galaxy Tab A 10.5           NaT         NaT
# 253      Galaxy Tab A Plus 8 (2019)           NaT         NaT
# 254             Galaxy Tab S5e 10.5           NaT         NaT
# 257          Galaxy Tab 10.1 (2016)           NaT         NaT
#
#         quarterly_start       quarterly_end    biannually_start  \
# 87  2019-10-08 22:18:41 2021-08-02 17:23:45 2021-08-06 07:29:59
# 88  2020-04-08 23:58:41 2022-04-03 17:02:57 2022-04-05 01:36:26
# 89  2020-09-14 17:19:27 2022-09-25 04:28:13 2022-10-15 22:30:50
# 90  2021-06-08 17:09:04                 NaT                 NaT
# 91  2018-03-08 21:26:30 2021-11-27 20:58:55                 NaT
# 92  2019-10-08 22:18:41                 NaT                 NaT
# 93  2020-10-12 20:04:56                 NaT                 NaT
# 94  2019-10-01 12:43:14 2021-10-04 23:40:50 2021-10-05 16:13:36
# 95  2020-03-03 11:31:08 2022-02-08 00:01:56 2022-02-08 15:41:26
# 96  2020-05-25 22:54:03                 NaT                 NaT
# 97  2020-09-14 17:19:27                 NaT                 NaT
# 98  2020-09-14 17:19:27                 NaT 2022-09-07 15:36:06
# 99  2021-06-08 17:09:04                 NaT                 NaT
# 139 2018-09-06 06:44:56 2019-10-01 12:43:14 2019-10-08 22:18:41
# 140 2019-05-20 07:22:25 2020-08-06 10:02:12 2020-09-14 17:19:27
# 141 2019-05-20 07:22:25 2020-08-06 10:02:12 2020-09-14 17:19:27
# 142 2019-04-05 15:35:10 2019-11-26 01:44:41 2020-03-03 11:31:08
# 143 2019-04-05 15:35:10 2021-05-02 10:00:07 2021-05-04 03:49:41
# 144                 NaT                 NaT 2021-05-04 03:49:41
# 145 2019-05-20 07:22:25 2021-05-02 10:00:07 2021-05-04 03:49:41
# 153 2019-05-20 07:22:25 2021-02-03 21:53:12                 NaT
# 161 2018-06-14 12:46:25 2019-02-02 23:33:05 2019-04-05 15:35:10
# 162                 NaT                 NaT 2019-05-20 07:22:25
# 168                 NaT 2019-02-02 23:33:05 2019-04-05 15:35:10
# 169 2018-04-03 20:45:30 2019-02-02 23:33:05 2019-04-05 15:35:10
# 181 2021-02-03 23:51:18 2021-05-02 10:00:07                 NaT
# 198 2022-01-12 01:32:51                 NaT                 NaT
# 199 2022-03-08 15:54:00                 NaT                 NaT
# 200 2022-03-08 15:54:00                 NaT                 NaT
# 201 2022-03-08 15:54:00                 NaT                 NaT
# 215 2022-09-07 15:36:06                 NaT                 NaT
# 234                 NaT 2019-02-02 23:33:05 2019-04-05 15:35:10
# 235 2018-09-06 06:44:56 2019-04-29 04:00:34                 NaT
# 236 2018-06-14 12:46:25 2019-02-02 23:33:05                 NaT
# 237 2018-09-06 06:44:56 2019-04-29 04:00:34                 NaT
# 253 2019-04-05 15:35:10 2019-04-29 04:00:34                 NaT
# 254 2019-04-05 15:35:10 2019-04-29 04:00:34                 NaT
# 257 2018-04-03 20:45:30 2018-04-03 20:45:30                 NaT
#
#          biannually_end wearable_start  wearable_end monthly_duration  \
# 87                  NaT            NaN           NaN              NaT
# 88                  NaT            NaN           NaN              NaT
# 89                  NaT            NaN           NaN              NaT
# 90                  NaT            NaN           NaN              NaT
# 91                  NaT            NaN           NaN              NaT
# 92                  NaT            NaN           NaN              NaT
# 93                  NaT            NaN           NaN              NaT
# 94                  NaT            NaN           NaN              NaT
# 95                  NaT            NaN           NaN              NaT
# 96                  NaT            NaN           NaN              NaT
# 97                  NaT            NaN           NaN              NaT
# 98                  NaT            NaN           NaN              NaT
# 99                  NaT            NaN           NaN              NaT
# 139 2021-10-04 23:40:50            NaN           NaN              NaT
# 140 2022-09-06 03:13:18            NaN           NaN              NaT
# 141 2022-09-06 03:13:18            NaN           NaN              NaT
# 142 2021-11-01 20:22:48            NaN           NaN              NaT
# 143                 NaT            NaN           NaN              NaT
# 144                 NaT            NaN           NaN              NaT
# 145                 NaT            NaN           NaN              NaT
# 153                 NaT            NaN           NaN              NaT
# 161 2020-07-06 17:50:48            NaN           NaN              NaT
# 162 2021-03-26 03:39:22            NaN           NaN              NaT
# 168 2019-10-01 12:43:14            NaN           NaN              NaT
# 169 2019-10-01 12:43:14            NaN           NaN              NaT
# 181                 NaT            NaN           NaN              NaT
# 198                 NaT            NaN           NaN              NaT
# 199                 NaT            NaN           NaN              NaT
# 200                 NaT            NaN           NaN              NaT
# 201                 NaT            NaN           NaN              NaT
# 215                 NaT            NaN           NaN              NaT
# 234 2019-04-29 04:00:34            NaN           NaN              NaT
# 235                 NaT            NaN           NaN              NaT
# 236                 NaT            NaN           NaN              NaT
# 237                 NaT            NaN           NaN              NaT
# 253                 NaT            NaN           NaN              NaT
# 254                 NaT            NaN           NaN              NaT
# 257                 NaT            NaN           NaN              NaT
#
#     quarterly_duration biannually_duration
# 87   663 days 19:05:04                 NaT
# 88   724 days 17:04:16                 NaT
# 89   740 days 11:08:46                 NaT
# 90                 NaT                 NaT
# 91  1359 days 23:32:25                 NaT
# 92                 NaT                 NaT
# 93                 NaT                 NaT
# 94   734 days 10:57:36                 NaT
# 95   706 days 12:30:48                 NaT
# 96                 NaT                 NaT
# 97                 NaT                 NaT
# 98                 NaT                 NaT
# 99                 NaT                 NaT
# 139  390 days 05:58:18   727 days 01:22:09
# 140  444 days 02:39:47   721 days 09:53:51
# 141  444 days 02:39:47   721 days 09:53:51
# 142  234 days 10:09:31   608 days 08:51:40
# 143  757 days 18:24:57                 NaT
# 144                NaT                 NaT
# 145  713 days 02:37:42                 NaT
# 153  625 days 14:30:47                 NaT
# 161  233 days 10:46:40   458 days 02:15:38
# 162                NaT   675 days 20:16:57
# 168                NaT   178 days 21:08:04
# 169  305 days 02:47:35   178 days 21:08:04
# 181   87 days 10:08:49                 NaT
# 198                NaT                 NaT
# 199                NaT                 NaT
# 200                NaT                 NaT
# 201                NaT                 NaT
# 215                NaT                 NaT
# 234                NaT    23 days 12:25:24
# 235  234 days 21:15:38                 NaT
# 236  233 days 10:46:40                 NaT
# 237  234 days 21:15:38                 NaT
# 253   23 days 12:25:24                 NaT
# 254   23 days 12:25:24                 NaT
# 257    0 days 00:00:00                 NaT

# %% [markdown]
# # 2. Xiaomi

# %%
import glob
import pandas as pd
from datetime import datetime
import os

def excel_to_dataframe(excel_path):
    df1 = pd.read_excel(excel_path, sheet_name = 'Monthly', usecols = 'A', names=['phone_model'],header=None)
    df1['support'] = 'Monthly'
    df1['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')

    df2 = pd.read_excel(excel_path, sheet_name = 'Quarterly', usecols = 'A', names=['phone_model'],header=None)
    df2['support'] = 'Quarterly'
    df2['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')

    try:
        df3 = pd.read_excel(excel_path, sheet_name = 'Other', usecols = 'A', names=['phone_model'],header=None)
        df3['support'] = 'Biannually'
        df3['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')
    except ValueError:
        try: 
            df3 = pd.read_excel(excel_path, sheet_name = 'Biannual', usecols = 'A', names=['phone_model'],header=None)
            df3['support'] = 'Biannually'
            df3['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')
        except ValueError:
            df3 = pd.DataFrame([])
            
        
        
    try:
        df4 = pd.read_excel(excel_path, sheet_name = 'Wearable', usecols = 'A', names=['phone_model'],header=None)
        df4['support'] = 'Wearable'
        df4['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')
    except ValueError:
        df4 = pd.DataFrame([])

    df = pd.concat([df1,df2,df3,df4])
    return df


def get_support_timeline(phone,dataset):

    df = dataset
    
    #print('Getting support timeline for {}!'.format(phone))
    
    df_phone = df[df.phone_model == phone].sort_values(by='date')
    
    try:
        monthly_start = df_phone[df_phone.support == 'Monthly'].iloc[0]['date']
        monthly_end = df_phone[df_phone.support == 'Monthly'].iloc[-1]['date']
    except IndexError:
        monthly_start = None
        monthly_end = None
        
    try: 
        quarterly_start = df_phone[df_phone.support == 'Quarterly'].iloc[0]['date']
        quarterly_end = df_phone[df_phone.support == 'Quarterly'].iloc[-1]['date']
    except IndexError:
        quarterly_start = None
        quarterly_end = None
        
    try:
        biannually_start = df_phone[df_phone.support == 'Biannually'].iloc[0]['date']
        biannually_end = df_phone[df_phone.support == 'Biannually'].iloc[-1]['date']
    except IndexError:
        biannually_start = None
        biannually_end = None
    
    try:
        wearable_start = df_phone[df_phone.support == 'Wearable'].iloc[0]['date']
        wearable_end = df_phone[df_phone.support == 'Wearable'].iloc[-1]['date']
    except IndexError:
        wearable_start = None
        wearable_end = None
    result = [monthly_start,monthly_end,quarterly_start,quarterly_end,biannually_start,biannually_end,wearable_start,wearable_end]
    
    return result

dir_path = '../Data/Xiaomi/Xiaomi-device-support-lists/'

print('Getting lists from {}'.format(dir_path))

excel_files = glob.glob(dir_path + '*.xlsx')
df_final_xiaomi = pd.DataFrame([])
for file in excel_files[:]:
    df_new = excel_to_dataframe(file)
    df_final_xiaomi = pd.concat([df_final_xiaomi,df_new],ignore_index=True)

print('Converting excel files to DataFrame is done!')

df_timelines_xiaomi = pd.DataFrame([])
for phone in df_final_xiaomi['phone_model'].unique():
    
    support_timeline = get_support_timeline(phone,df_final_xiaomi)
    
    df_new = pd.DataFrame({"phone": phone, 
                           "monthly_start": support_timeline[0],
                           "monthly_end": support_timeline[1],
                           "quarterly_start": support_timeline[2],
                           "quarterly_end": support_timeline[3],
                           "biannually_start": support_timeline[4],
                           "biannually_end": support_timeline[5],
                           "wearable_start": support_timeline[6],
                           "wearable_end": support_timeline[7]},
                          index=[0])
 
    
    df_timelines_xiaomi = pd.concat([df_timelines_xiaomi,df_new],ignore_index=True)
    
df_timelines_xiaomi.to_csv('../Data/Xiaomi/timelines_Xiaomi.csv',index=False)

df_timelines_xiaomi.head()
# Out:
# Getting lists from ../Data/Xiaomi/Xiaomi-device-support-lists/
# Converting excel files to DataFrame is done!
#         phone        monthly_start          monthly_end      quarterly_start  \
# 0       Mi A3  2021-01-27 17:45:16  2022-10-31 17:52:22  2021-01-27 17:45:16
# 1       Mi A2  2021-01-27 17:45:16  2022-10-31 17:52:22                 None
# 2  Mi A2 Lite  2021-01-27 17:45:16  2022-10-31 17:52:22                 None
# 3  Mi 10T Pro                 None                 None  2021-01-27 17:45:16
# 4     Mi 10 T                 None                 None  2021-01-27 17:45:16
#
#          quarterly_end biannually_start biannually_end wearable_start  \
# 0  2022-10-31 17:52:22             None           None           None
# 1                 None             None           None           None
# 2                 None             None           None           None
# 3  2022-10-31 17:52:22             None           None           None
# 4  2022-10-31 17:52:22             None           None           None
#
#   wearable_end
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None

# %%
import os
import pandas as pd
from datetime import datetime
from datetime import date

# Folder path
folder_path = '../Data/Xiaomi/xiaomi_archieve_data_eos/'

# Initialize empty DataFrame
df_xiaomi_eos = pd.DataFrame(columns=['Date', 'Brand', 'Source URL'])

# Go through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.xlsx'):
        # Get timestamp from the filename
        timestamp = filename.split('.')[0]
        date = datetime.strptime(timestamp, '%Y%m%d%H%M%S').date() 

        # Read excel file
        excel_data = pd.read_excel(os.path.join(folder_path, filename))

        # Check if dataframe is empty
        if not excel_data.empty:
            # Source URL is the first element of 'Source URL' column
            source_url = excel_data['Source URL'].iloc[0]
            
            my_list = list(set(excel_data['Mi'].to_list()+excel_data['Redmi'].to_list()+excel_data['POCO'].to_list()))

            cleanedList = [x for x in my_list if str(x) != 'nan']

            # Create a temporary DataFrame from cleanedList and append it to df
            temp_df = pd.DataFrame({
                'Date': [date]*len(cleanedList), 
                'Brand': cleanedList, 
                'Source URL': [source_url]*len(cleanedList)
            })
            df_xiaomi_eos = df_xiaomi_eos.append(temp_df, ignore_index=True)


df_xiaomi_eos = df_xiaomi_eos.sort_values('Date')
df_xiaomi_eos.head()
# Out:
#             Date      Brand                                         Source URL
# 2741  2021-10-12   Redmi Y2  https://web.archive.org/web/20211012105859/htt...
# 2779  2021-10-12  MI Note 2  https://web.archive.org/web/20211012105859/htt...
# 2780  2021-10-12       MI 6  https://web.archive.org/web/20211012105859/htt...
# 2781  2021-10-12      MI 5X  https://web.archive.org/web/20211012105859/htt...
# 2782  2021-10-12   Redmi 4X  https://web.archive.org/web/20211012105859/htt...

# %%
appearance_df = pd.DataFrame({
    'First Appearance': df_xiaomi_eos.groupby('Brand')['Date'].min(),
    'Last Appearance': df_xiaomi_eos.groupby('Brand')['Date'].max()
})

# Sort appearance_df by 'First Appearance'
appearance_df = appearance_df.sort_values('First Appearance')

appearance_df
# Out:
#                    First Appearance Last Appearance
# Brand
# MI 1                     2021-10-12      2022-08-24
# MIX 2                    2021-10-12      2023-03-06
# MIX 2S                   2021-10-12      2023-03-06
# MIX 3                    2021-10-12      2023-03-06
# Redmi 1                  2021-10-12      2023-03-06
# ...                             ...             ...
# Redmi K30 5G Speed       2023-02-04      2023-03-06
# Redmi 8A Dual            2023-02-04      2023-03-06
# Redmi Note 5 Pro         2023-02-04      2023-03-06
# Redmi Note 8 (IN)        2023-02-04      2023-03-06
# Redmi Go                 2023-02-04      2023-03-06
#
# [95 rows x 2 columns]

# %% [markdown]
# # 3. Oppo

# %%
import glob
import pandas as pd
from datetime import datetime
import os

def excel_to_dataframe(excel_path):
    df1 = pd.read_excel(excel_path, sheet_name = 'monthly', usecols = 'A', names=['phone_model'],header=None)
    df1['support'] = 'monthly'
    df1['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')

    df2 = pd.read_excel(excel_path, sheet_name = 'quarterly', usecols = 'A', names=['phone_model'],header=None)
    df2['support'] = 'quarterly'
    df2['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')
    
    df3 = pd.read_excel(excel_path, sheet_name = 'others', usecols = 'A', names=['phone_model'],header=None)
    df3['support'] = 'others'
    df3['date'] = datetime.strptime(os.path.splitext(os.path.basename(excel_path))[0],'%Y%m%d%H%M%S')

    df = pd.concat([df1,df2,df3])
    return df


def get_support_timeline(phone,dataset):

    df = dataset
    
    #print('Getting support timeline for {}!'.format(phone))
    
    df_phone = df[df.phone_model == phone].sort_values(by='date')
    
    try:
        monthly_start = df_phone[df_phone.support == 'monthly'].iloc[0]['date']
        monthly_end = df_phone[df_phone.support == 'monthly'].iloc[-1]['date']
    except IndexError:
        monthly_start = None
        monthly_end = None
        
    try: 
        quarterly_start = df_phone[df_phone.support == 'quarterly'].iloc[0]['date']
        quarterly_end = df_phone[df_phone.support == 'quarterly'].iloc[-1]['date']
    except IndexError:
        quarterly_start = None
        quarterly_end = None
        
    try: 
        others_start = df_phone[df_phone.support == 'others'].iloc[0]['date']
        others_end = df_phone[df_phone.support == 'others'].iloc[-1]['date']
    except IndexError:
        others_start = None
        others_end = None
        

    result = [monthly_start,monthly_end,quarterly_start,quarterly_end,others_start,others_end]
    
    return result

dir_path = '../Data/Oppo/oppo-support-lists/'

print('Getting lists from {}'.format(dir_path))

excel_files = glob.glob(dir_path + '*.xlsx')
df_final_oppo = pd.DataFrame([])
for file in excel_files[:]:
    df_new = excel_to_dataframe(file)
    df_final_oppo = pd.concat([df_final_oppo,df_new],ignore_index=True)

print('Converting excel files to DataFrame is done!')

df_timelines_oppo = pd.DataFrame([])
for phone in df_final_oppo['phone_model'].unique():
    
    support_timeline = get_support_timeline(phone,df_final_oppo)
    
    df_new = pd.DataFrame({"phone": phone, 
                           "monthly_start": support_timeline[0],
                           "monthly_end": support_timeline[1],
                           "quarterly_start": support_timeline[2],
                           "quarterly_end": support_timeline[3],
                           "others_start": support_timeline[4],
                           "others_end": support_timeline[5]},
                          index=[0])
 
    
    df_timelines_oppo = pd.concat([df_timelines_oppo,df_new],ignore_index=True)
    

# split the column values into two columns
df_timelines_oppo[['model_name', 'model_number']] = df_timelines_oppo['phone'].str.split('（', expand=True)
df_timelines_oppo['model_number'] = df_timelines_oppo['model_number'].str.replace('）', '')
df_timelines_oppo['model_name_v2'] = df_timelines_oppo['model_name'].str.split('(', expand=True)[0]

df_timelines_oppo['monthly_duration'] = (df_timelines_oppo['monthly_end']-df_timelines_oppo['monthly_start']).dt.days
df_timelines_oppo['quarterly_duration'] = (df_timelines_oppo['quarterly_end']-df_timelines_oppo['quarterly_start']).dt.days

df_timelines_oppo.to_csv('../Data/Oppo/timelines_Oppo.csv',index=False,encoding="utf-8")

df_timelines_oppo
# Out:
# Getting lists from ../Data/Oppo/oppo-support-lists/
# Converting excel files to DataFrame is done!
#                                    phone        monthly_start  \
# 0               Find X2（CPH2023、CPH1921）  2022-10-11 18:51:30
# 1                   Find X2 Pro（CPH2025）  2022-10-11 18:51:30
# 2                        Find X3（PEDM00）  2022-10-11 18:51:30
# 3                   Find X3 Neo（CPH2207）  2022-10-11 18:51:30
# 4    Find X3 Pro（PEEM00、CPH2173、CPH2305）  2022-10-11 18:51:30
# ..                                   ...                  ...
# 323                 Reno5 Pro 5G（PDSM00）                 None
# 324    Reno6 pro（CPH2247、CPH2249、PEPM00）                 None
# 325                        Reno7（PFJM10）                 None
# 326                    Reno7 pro（PFDM00）                 None
# 327                     Reno7 SE（PFCM00）                 None
#
#              monthly_end quarterly_start quarterly_end         others_start  \
# 0    2023-03-07 19:24:15             NaN           NaN                  NaT
# 1    2023-03-07 19:24:15             NaN           NaN                  NaT
# 2    2023-03-07 19:24:15             NaN           NaN  2021-01-21 17:16:59
# 3    2023-03-07 19:24:15             NaN           NaN  2021-01-21 17:16:59
# 4    2023-03-07 19:24:15             NaN           NaN                 None
# ..                   ...             ...           ...                  ...
# 323                 None            None          None  2021-01-21 17:16:59
# 324                 None            None          None  2021-01-21 17:16:59
# 325                 None            None          None  2021-01-21 17:16:59
# 326                 None            None          None  2021-01-21 17:16:59
# 327                 None            None          None  2021-01-21 17:16:59
#
#               others_end    model_name            model_number model_name_v2  \
# 0                    NaT       Find X2         CPH2023、CPH1921       Find X2
# 1                    NaT   Find X2 Pro                 CPH2025   Find X2 Pro
# 2    2022-06-09 07:23:31       Find X3                  PEDM00       Find X3
# 3    2022-06-09 07:23:31   Find X3 Neo                 CPH2207   Find X3 Neo
# 4                   None   Find X3 Pro  PEEM00、CPH2173、CPH2305   Find X3 Pro
# ..                   ...           ...                     ...           ...
# 323  2022-06-09 07:23:31  Reno5 Pro 5G                  PDSM00  Reno5 Pro 5G
# 324  2022-06-09 07:23:31     Reno6 pro  CPH2247、CPH2249、PEPM00     Reno6 pro
# 325  2022-06-09 07:23:31         Reno7                  PFJM10         Reno7
# 326  2022-06-09 07:23:31     Reno7 pro                  PFDM00     Reno7 pro
# 327  2022-06-09 07:23:31      Reno7 SE                  PFCM00      Reno7 SE
#
#      monthly_duration  quarterly_duration
# 0               147.0                 NaN
# 1               147.0                 NaN
# 2               147.0                 NaN
# 3               147.0                 NaN
# 4               147.0                 NaN
# ..                ...                 ...
# 323               NaN                 NaN
# 324               NaN                 NaN
# 325               NaN                 NaN
# 326               NaN                 NaN
# 327               NaN                 NaN
#
# [328 rows x 12 columns]

# %%
df_timelines_oppo['phone']
# Out:
#                 0                        1
# 0         Find X2         CPH2023、CPH1921）
# 1     Find X2 Pro                 CPH2025）
# 2         Find X3                  PEDM00）
# 3     Find X3 Neo                 CPH2207）
# 4     Find X3 Pro  PEEM00、CPH2173、CPH2305）
# ..            ...                      ...
# 323  Reno5 Pro 5G                  PDSM00）
# 324     Reno6 pro  CPH2247、CPH2249、PEPM00）
# 325         Reno7                  PFJM10）
# 326     Reno7 pro                  PFDM00）
# 327      Reno7 SE                  PFCM00）
#
# [328 rows x 2 columns]

# %%
df_timelines[df_timelines['phone'].str.contains('Reno4')]
# Out:
#                                            phone monthly_start monthly_end  \
# 27                        Reno4（CPH2113、CPH2109）          None        None
# 28               Reno4 5G（PDPM00、PDPT00、CPH2091）          None        None
# 29                              Reno4 F（CPH2209）          None        None
# 30                           Reno4 Lite（CPH2125）          None        None
# 31      Reno4 Pro（PDNT00、PDNM00、CPH2109、CPH2113）          None        None
# 32                         Reno4 Pro 5G（CPH2089）          None        None
# 33                       Reno4 SE（PEAT00、PEAM00）          None        None
# 34                           Reno4 Z 5G（CPH2065）          None        None
# 154                       Reno4(CPH2113、CPH2109)          None        None
# 155                            Reno4 5G(CPH2091)          None        None
# 156                        Reno4 Pro 5G(CPH2089)          None        None
# 157                           Reno4Z 5G(CPH2065)          None        None
# 232                   Reno4 SE 5G（PEAM00、PEAT00）          None        None
# 233  Reno4 Pro 5G（PDNM00、PDNT00、CPH2089、CPH2109）          None        None
# 234              Reno4 5G（PDPT00、PDPM00、CPH2091）          None        None
# 235             Reno4 Pro（PDNT00、PDNM00、CPH2089）          None        None
# 236                      Reno4 （CPH2091、CPH2113）          None        None
# 237                           Reno4Z 5G（CPH2065）          None        None
# 238                  Reno4 Lite（CPH2119、CPH2125）          None        None
#
#          quarterly_start        quarterly_end         others_start  \
# 27   2022-10-11 18:51:30  2023-03-07 19:24:15                 None
# 28   2022-10-11 18:51:30  2023-03-07 19:24:15                 None
# 29   2021-01-21 17:16:59  2023-03-07 19:24:15                 None
# 30   2022-10-11 18:51:30  2023-03-07 19:24:15                 None
# 31   2022-10-11 18:51:30  2023-03-07 19:24:15                 None
# 32   2022-10-11 18:51:30  2023-03-07 19:24:15                 None
# 33   2022-10-11 18:51:30  2023-03-07 19:24:15                 None
# 34   2022-10-11 18:51:30  2023-03-07 19:24:15                 None
# 154                  NaT                  NaT  2022-10-11 18:51:30
# 155                  NaT                  NaT  2022-10-11 18:51:30
# 156                  NaT                  NaT  2022-10-11 18:51:30
# 157                  NaT                  NaT  2022-10-11 18:51:30
# 232  2021-01-21 17:16:59  2022-06-09 07:23:31                 None
# 233  2021-01-21 17:16:59  2022-06-09 07:23:31                 None
# 234  2021-01-21 17:16:59  2022-06-09 07:23:31                 None
# 235  2021-01-21 17:16:59  2022-06-09 07:23:31                 None
# 236  2021-01-21 17:16:59  2022-06-09 07:23:31                 None
# 237  2021-01-21 17:16:59  2022-06-09 07:23:31                 None
# 238  2021-01-21 17:16:59  2022-06-09 07:23:31                 None
#
#               others_end              model_name  \
# 27                  None                   Reno4
# 28                  None                Reno4 5G
# 29                  None                 Reno4 F
# 30                  None              Reno4 Lite
# 31                  None               Reno4 Pro
# 32                  None            Reno4 Pro 5G
# 33                  None                Reno4 SE
# 34                  None              Reno4 Z 5G
# 154  2023-03-07 19:24:15  Reno4(CPH2113、CPH2109)
# 155  2023-03-07 19:24:15       Reno4 5G(CPH2091)
# 156  2023-03-07 19:24:15   Reno4 Pro 5G(CPH2089)
# 157  2023-03-07 19:24:15      Reno4Z 5G(CPH2065)
# 232                 None             Reno4 SE 5G
# 233                 None            Reno4 Pro 5G
# 234                 None                Reno4 5G
# 235                 None               Reno4 Pro
# 236                 None                  Reno4
# 237                 None               Reno4Z 5G
# 238                 None              Reno4 Lite
#
#                       model_number model_name_v2
# 27                 CPH2113、CPH2109         Reno4
# 28           PDPM00、PDPT00、CPH2091      Reno4 5G
# 29                         CPH2209       Reno4 F
# 30                         CPH2125    Reno4 Lite
# 31   PDNT00、PDNM00、CPH2109、CPH2113     Reno4 Pro
# 32                         CPH2089  Reno4 Pro 5G
# 33                   PEAT00、PEAM00      Reno4 SE
# 34                         CPH2065    Reno4 Z 5G
# 154                           None         Reno4
# 155                           None      Reno4 5G
# 156                           None  Reno4 Pro 5G
# 157                           None     Reno4Z 5G
# 232                  PEAM00、PEAT00   Reno4 SE 5G
# 233  PDNM00、PDNT00、CPH2089、CPH2109  Reno4 Pro 5G
# 234          PDPT00、PDPM00、CPH2091      Reno4 5G
# 235          PDNT00、PDNM00、CPH2089     Reno4 Pro
# 236                CPH2091、CPH2113        Reno4
# 237                        CPH2065     Reno4Z 5G
# 238                CPH2119、CPH2125    Reno4 Lite

# %% [markdown]
# # 4. Google

# %%
df_timeline_google = pd.read_excel('../Data/Google/Google-support-list.xlsx')

df_timeline_google.head()
# Out:
#                    Phone Guaranteed Android version updates until at least:  \
# 0  Pixel 7 & Pixel 7 Pro                                         2025-10-01
# 1  Pixel 6 & Pixel 6 Pro                                         2024-10-01
# 2               Pixel 6a                                         2025-07-01
# 3       Pixel 5a with 5G                                         2024-08-01
# 4                Pixel 5                                         2023-10-01
#
#   Guaranteed security updates until at least:  Unnamed: 3  \
# 0                                  2027-10-01         NaN
# 1                                  2026-10-01         NaN
# 2                                  2027-07-01         NaN
# 3                                  2024-08-01         NaN
# 4                                  2023-10-01         NaN
#
#                                           Unnamed: 4
# 0                                                NaN
# 1  *Nexus devices get security updates for at lea...
# 2                                                NaN
# 3                                                NaN
# 4  *Pixel phones get security updates for at leas...

# %%
import os
import pandas as pd
from datetime import datetime

# Folder path
folder_path = '../Data/Xiaomi/xiaomi_archieve_data_eos/'

# Initialize empty DataFrame
df_xiaomi_eos = pd.DataFrame(columns=['Date', 'Brand', 'Source URL'])

# Go through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.xlsx'):
        # Get timestamp from the filename
        timestamp = filename.split('.')[0]
        date = datetime.strptime(timestamp, '%Y%m%d%H%M%S').date() 

        # Read excel file
        excel_data = pd.read_excel(os.path.join(folder_path, filename))

        # Check if dataframe is empty
        if not excel_data.empty:
            # Source URL is the first element of 'Source URL' column
            source_url = excel_data['Source URL'].iloc[0]
            
            my_list = list(set(excel_data['Mi'].to_list()+excel_data['Redmi'].to_list()+excel_data['POCO'].to_list()))

            cleanedList = [x for x in my_list if str(x) != 'nan']

            # Create a temporary DataFrame from cleanedList and append it to df
            temp_df = pd.DataFrame({
                'Date': [date]*len(cleanedList), 
                'Brand': cleanedList, 
                'Source URL': [source_url]*len(cleanedList)
            })
            df_xiaomi_eos = df_xiaomi_eos.append(temp_df, ignore_index=True)


df_xiaomi_eos = df_xiaomi_eos.sort_values('Date')
df_xiaomi_eos.head()
# Out:
#             Date          Brand  \
# 2741  2021-10-12  MI Pad 4 Plus
# 2779  2021-10-12       MI MAX 3
# 2780  2021-10-12          MI 4c
# 2781  2021-10-12       Redmi 1S
# 2782  2021-10-12       Redmi 4X
#
#                                              Source URL
# 2741  https://web.archive.org/web/20211012105859/htt...
# 2779  https://web.archive.org/web/20211012105859/htt...
# 2780  https://web.archive.org/web/20211012105859/htt...
# 2781  https://web.archive.org/web/20211012105859/htt...
# 2782  https://web.archive.org/web/20211012105859/htt...
